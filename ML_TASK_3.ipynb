# %%
import numpy as np
import os
import pandas as pd
from skimage.transform import resize
from skimage.io import imread
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVC

# %%
datadir = 'train_3/'
target_arr = []
flat_data_arr = []

# %%
for i in os.listdir(datadir):
    img_array = imread(os.path.join(datadir,i))
    img_resized = resize(img_array,(150,150,3))
    flat_data_arr.append(img_resized.flatten())
    if('cat' in i):
        target_arr.append(0)
    if('dog' in i):
        target_arr.append(1)
target = np.array(target_arr)
flat_data = np.array(flat_data_arr)

# %%
category = ["cat","dog"]
df = pd.DataFrame(flat_data)
df['target'] = target
df['target_names'] = df["target"].apply(lambda x : category[x])
df[245:255]
# Out:
#             0         1         2         3         4         5         6  \
# 245  0.720013  0.769739  0.857002  0.913768  0.912338  0.962213  0.992997
# 246  0.370539  0.307896  0.307588  0.377454  0.317797  0.306903  0.383935
# 247  0.122064  0.112674  0.190914  0.123247  0.130605  0.174512  0.178857
# 248  0.522044  0.460052  0.481691  0.545836  0.483839  0.513772  0.570269
# 249  0.272468  0.356256  0.132111  0.269789  0.359656  0.139398  0.271002
# 250  0.485840  0.458389  0.489761  0.479936  0.452485  0.483858  0.482643
# 251  0.470568  0.416175  0.338666  0.425315  0.356470  0.279792  0.400081
# 252  0.482899  0.412313  0.403045  0.493105  0.425029  0.414930  0.493912
# 253  0.356066  0.336458  0.324694  0.356066  0.336458  0.324694  0.356066
# 254  0.524283  0.532126  0.488989  0.503230  0.511073  0.467936  0.499241
#
#             7         8         9  ...     67492     67493     67494  \
# 245  0.969058  0.982257  0.982230  ...  0.524425  0.508297  0.497231
# 246  0.325114  0.305113  0.384650  ...  0.582751  0.734063  0.374779
# 247  0.194629  0.207072  0.162911  ...  0.114347  0.111543  0.108215
# 248  0.508827  0.530409  0.486486  ...  0.524985  0.405579  0.438609
# 249  0.372785  0.158576  0.271089  ...  0.276074  0.288260  0.275317
# 250  0.455192  0.486565  0.485375  ...  0.454639  0.466184  0.409171
# 251  0.326674  0.270684  0.400924  ...  0.297684  0.270594  0.468925
# 252  0.438494  0.424719  0.491391  ...  0.671890  0.723915  0.760113
# 253  0.336458  0.324694  0.356066  ...  0.170973  0.143522  0.242997
# 254  0.507085  0.463947  0.455266  ...  0.578375  0.508814  0.673867
#
#         67495     67496     67497     67498     67499  target  target_names
# 245  0.495241  0.476727  0.486709  0.498572  0.497334       1           dog
# 246  0.501122  0.661582  0.379627  0.509597  0.661287       1           dog
# 247  0.123076  0.119156  0.099044  0.107915  0.103993       1           dog
# 248  0.496745  0.452598  0.435249  0.445453  0.459680       1           dog
# 249  0.240363  0.244945  0.245054  0.211867  0.210112       1           dog
# 250  0.386226  0.394215  0.421005  0.397475  0.405319       1           dog
# 251  0.315521  0.287559  0.481161  0.328602  0.300186       1           dog
# 252  0.674897  0.737466  0.777797  0.686797  0.749191       1           dog
# 253  0.164566  0.137115  0.259265  0.180834  0.153383       1           dog
# 254  0.662134  0.595451  0.570311  0.555103  0.489584       1           dog
#
# [10 rows x 67502 columns]

# %%
x = df.drop(["target","target_names"],axis=1)
y = df.target

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2)

# %%
GCV = GridSearchCV(SVC(kernel="poly"),{
    'C':[10,20,50],
    'kernel':["poly","rbf"]
},return_train_score=False)

# %%
svm = SVC()
svm.fit(x_train,y_train)
# Out:
# SVC()

# %%
svm.score(x_test,y_test)
# Out:
# 0.8404907975460123
