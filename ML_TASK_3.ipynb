# %%
import numpy as np
import os
import pandas as pd
from skimage.transform import resize
from skimage.io import imread
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVC

# %%
datadir = 'train_3/'
target_arr = []
flat_data_arr = []

# %%
for i in os.listdir(datadir):
    img_array = imread(os.path.join(datadir,i))
    img_resized = resize(img_array,(150,150,3))
    flat_data_arr.append(img_resized.flatten())
    if('cat' in i):
        target_arr.append(0)
    if('dog' in i):
        target_arr.append(1)
target = np.array(target_arr)
flat_data = np.array(flat_data_arr)

# %%
category = ["cat","dog"]
df = pd.DataFrame(flat_data)
df['target'] = target
df['target_names'] = df["target"].apply(lambda x : category[x])
df[245:255]
# Out:
#             0         1         2         3         4         5         6  \
# 245  0.719242  0.770052  0.857816  0.913095  0.912966  0.962212  0.994359
# 246  0.370539  0.307896  0.307589  0.377454  0.317797  0.308123  0.383935
# 247  0.122211  0.112674  0.190006  0.125096  0.130787  0.170935  0.178885
# 248  0.523762  0.458671  0.482041  0.547551  0.482461  0.515215  0.571981
# 249  0.273358  0.355929  0.133733  0.271139  0.359280  0.139519  0.272467
# 250  0.485840  0.458389  0.489761  0.479936  0.452485  0.483858  0.482643
# 251  0.473972  0.415764  0.338664  0.424851  0.356458  0.278543  0.399811
# 252  0.482876  0.412324  0.403045  0.490836  0.426163  0.414930  0.494258
# 253  0.356066  0.336458  0.324694  0.356066  0.336458  0.324694  0.356066
# 254  0.524283  0.532126  0.488989  0.503230  0.511073  0.467936  0.499241
#
#             7         8         9  ...     67492     67493     67494  \
# 245  0.966940  0.981721  0.982495  ...  0.524425  0.508815  0.497495
# 246  0.325114  0.304325  0.384650  ...  0.582588  0.734063  0.378216
# 247  0.194736  0.203241  0.165003  ...  0.115159  0.111543  0.108213
# 248  0.507641  0.530936  0.488179  ...  0.527530  0.400767  0.438050
# 249  0.372558  0.158675  0.270794  ...  0.276078  0.288252  0.275317
# 250  0.455192  0.486565  0.485375  ...  0.454639  0.466184  0.409171
# 251  0.327354  0.268493  0.400083  ...  0.297809  0.270469  0.468925
# 252  0.438369  0.424719  0.493041  ...  0.671478  0.723087  0.761055
# 253  0.336458  0.324694  0.356066  ...  0.170973  0.143522  0.242997
# 254  0.507085  0.463947  0.455266  ...  0.578379  0.508804  0.673966
#
#         67495     67496     67497     67498     67499  target  target_names
# 245  0.494617  0.476463  0.485044  0.498161  0.498999       1           dog
# 246  0.499442  0.661582  0.379835  0.509812  0.661287       1           dog
# 247  0.123077  0.119156  0.099044  0.107915  0.103993       1           dog
# 248  0.497294  0.453766  0.437081  0.444538  0.460738       1           dog
# 249  0.240699  0.244317  0.245054  0.212884  0.207769       1           dog
# 250  0.386226  0.394215  0.421005  0.397475  0.405319       1           dog
# 251  0.315543  0.287546  0.481161  0.328602  0.300189       1           dog
# 252  0.674044  0.738700  0.780952  0.685943  0.749193       1           dog
# 253  0.164566  0.137115  0.259265  0.180834  0.153383       1           dog
# 254  0.662085  0.595451  0.573948  0.553284  0.489584       1           dog
#
# [10 rows x 67502 columns]

# %%
x = df.drop(["target","target_names"],axis=1)
y = df.target

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2)

# %%
# GCV = GridSearchCV(SVC(kernel="poly"),{
#     'C':[10,20,50],
#     'kernel':["poly","rbf"]
# },return_train_score=False)

# %%
#GCV.fit(x_train,y_train)

# %%
#GCV.best_params_

# %%
#GCV.best_score_

# %%
svm = SVC()
svm.fit(x_train,y_train)
# Out:
# SVC()

# %%
svm.score(x_test,y_test)
# Out:
# 0.8404907975460123
